# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pi_vertical_garden.util as pvg
from pi_vertical_garden.util import *
import pandas as pd

# %%
ds = pvg.get_soil_data()

# %%
import matplotlib.pyplot as plt

# %%
dat = ds.iloc[-3:][pvg.COL_HUMIDITY]
dat.plot()

# %%
ds.index = pd.to_datetime(ds.index*10**9)

# %%
cols = ds.columns

# %%
dat = ds.iloc[0:][pvg.COL_HUMIDITY]

# %%
ds.iloc[1:][[pvg.COL_HUMIDITY]].plot(style='.')

# %%
pvg.get_soil_sensor_row()
# Out:
#               dew_point  humidity   temp
# dt_secs
# 1.563590e+09       6.73     50.49  17.92

# %%
pvg.valve_on()

# %%
pvg.valve_off()

# %%
def plot_col_ts(col):
    ds = get_soil_data()
    ds.index = pd.to_datetime(ds.index*10**9)
    ds = ds[[col]]
    ds.plot(style='.')

# %%
plot_col_ts(COL_HUMIDITY)

# %%
def plot_col_ts(col):
    ds = get_soil_data()
    ds.index = pd.to_datetime(ds.index*10**9)
    ds = ds[[col]]
    ds.plot(style='.')

def plot_cols():
    cols = [COL_DEW_POINT,COL_HUMIDITY,COL_TEMP]
    for c in cols:
        plot_col_ts(c)

# %%
plot_cols()

# %%
d
